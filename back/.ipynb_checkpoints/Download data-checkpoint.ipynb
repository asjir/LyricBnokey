# %%
import io, os, sys, requests
import numpy as np
import pandas as pd
import tensorflow as tf
url = 'https://api.musixmatch.com/ws/1.1/'
apikey = 'd8eaef84c24b7217a5ec54158eacd213'.encode('utf-8')

# %%
artist = requests.get(url+'track.search', {'apikey':apikey, 'q_artist':'prodigy'.encode('utf-8')})

# %%
artist.json()['message']['body']['track_list']#[0]#['artist']['artist_id']
# Out:
# [{'track': {'track_id': 123003777,
#    'track_name': 'Live',
#    'track_name_translation_list': [],
#    'track_rating': 34,
#    'commontrack_id': 11035988,
#    'instrumental': 0,
#    'explicit': 1,
#    'has_lyrics': 1,
#    'has_subtitles': 1,
#    'has_richsync': 0,
#    'num_favourite': 4,
#    'album_id': 25156079,
#    'album_name': 'H.N.I.C 3',
#    'artist_id': 13816,
#    'artist_name': 'Prodigy',
#    'track_share_url': 'https://www.musixmatch.com/lyrics/Prodigy/Live?utm_source=application&utm_campaign=api&utm_medium=University+of+Oxford%3A1409618372145',
#    'track_edit_url': 'https://www.musixmatch.com/lyrics/Prodigy/Live/edit?utm_source=application&utm_campaign=api&utm_medium=University+of+Oxford%3A1409618372145',
#    'restricted': 0,
#    'updated_time': '2014-02-10T18:38:28Z',
#    'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 1073,
#        'music_genre_parent_id': 18,
#        'music_genre_name': 'Hip-Hop',
#        'music_genre_name_extended': 'Hip Hop/Rap / Hip-Hop',
#        'music_genre_vanity': 'Hip-Hop-Rap-Hip-Hop'}},
#      {'music_genre': {'music_genre_id': 18,
#        'music_genre_parent_id': 34,
#        'music_genre_name': 'Hip Hop/Rap',
#        'music_genre_name_extended': 'Hip Hop/Rap',
#        'music_genre_vanity': 'Hip-Hop-Rap'}}]}}},
#  {'track': {'track_id': 1645765,
#    'track_name': 'Street Subpoena',
#    'track_name_translation_list': [],
#    'track_rating': 1,
#    'commontrack_id': 1602619,
#    'instrumental': 0,
#    'explicit': 1,
#    'has_lyrics': 1,
#    'has_subtitles': 0,
#    'has_richsync': 0,
#    'num_favourite': 0,
#    'album_id': 10353984,
#    'album_name': 'Muskabeatz',
#    'artist_id': 13816,
#    'artist_name': 'Prodigy',
#    'track_share_url': 'https://www.musixmatch.com/lyrics/Prodigy/Street-Subpoena?utm_source=application&utm_campaign=api&utm_medium=University+of+Oxford%3A1409618372145',
#    'track_edit_url': 'https://www.musixmatch.com/lyrics/Prodigy/Street-Subpoena/edit?utm_source=application&utm_campaign=api&utm_medium=University+of+Oxford%3A1409618372145',
#    'restricted': 0,
#    'updated_time': '2015-06-28T01:46:07Z',
#    'primary_genres': {'music_genre_list': []}}},
#  {'track': {'track_id': 852529,
#    'track_name': 'Rock Dat Sh*t',
#    'track_name_translation_list': [],
#    'track_rating': 17,
#    'commontrack_id': 1602607,
#    'instrumental': 0,
#    'explicit': 1,
#    'has_lyrics': 1,
#    'has_subtitles': 1,
#    'has_richsync': 0,
#    'num_favourite': 1,
#    'album_id': 10291142,
#    'album_name': 'H.N.I.C.',
#    'artist_id': 13816,
#    'artist_name': 'Prodigy',
#    'track_share_url': 'https://www.musixmatch.com/lyrics/Prodigy/Rock-Dat-Sh-t?utm_source=application&utm_campaign=api&utm_medium=University+of+Oxford%3A1409618372145',
#    'track_edit_url': 'https://www.musixmatch.com/lyrics/Prodigy/Rock-Dat-Sh-t/edit?utm_source=application&utm_campaign=api&utm_medium=University+of+Oxford%3A1409618372145',
#    'restricted': 0,
#    'updated_time': '2011-06-10T18:46:31Z',
#    'primary_genres': {'music_genre_list': []}}},
#  {'track': {'track_id': 53038654,
#    'track_name': 'Waddup Gz',
#    'track_name_translation_list': [],
#    'track_rating': 34,
#    'commontrack_id': 1602643,
#    'instrumental': 0,
#    'explicit': 1,
#    'has_lyrics': 1,
#    'has_subtitles': 0,
#    'has_richsync': 0,
#    'num_favourite': 1,
#    'album_id': 17060674,
#    'album_name': 'Product of the 80s',
#    'artist_id': 13816,
#    'artist_name': 'Prodigy',
#    'track_share_url': 'https://www.musixmatch.com/lyrics/Prodigy/Waddup-Gz?utm_source=application&utm_campaign=api&utm_medium=University+of+Oxford%3A1409618372145',
#    'track_edit_url': 'https://www.musixmatch.com/lyrics/Prodigy/Waddup-Gz/edit?utm_source=application&utm_campaign=api&utm_medium=University+of+Oxford%3A1409618372145',
#    'restricted': 0,
#    'updated_time': '2012-10-02T12:40:07Z',
#    'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 18,
#        'music_genre_parent_id': 34,
#        'music_genre_name': 'Hip Hop/Rap',
#        'music_genre_name_extended': 'Hip Hop/Rap',
#        'music_genre_vanity': 'Hip-Hop-Rap'}}]}}},
#  {'track': {'track_id': 852536,
#    'track_name': 'Delt With the Bullsh*t (feat. Havoc)',
#    'track_name_translation_list': [],
#    'track_rating': 1,
#    'commontrack_id': 1602537,
#    'instrumental': 0,
#    'explicit': 1,
#    'has_lyrics': 1,
#    'has_subtitles': 0,
#    'has_richsync': 0,
#    'num_favourite': 0,
#    'album_id': 10291142,
#    'album_name': 'H.N.I.C.',
#    'artist_id': 13816,
#    'artist_name': 'Prodigy',
#    'track_share_url': 'https://www.musixmatch.com/lyrics/Prodigy/Delt-With-the-Bullsh-t-feat-Havoc?utm_source=application&utm_campaign=api&utm_medium=University+of+Oxford%3A1409618372145',
#    'track_edit_url': 'https://www.musixmatch.com/lyrics/Prodigy/Delt-With-the-Bullsh-t-feat-Havoc/edit?utm_source=application&utm_campaign=api&utm_medium=University+of+Oxford%3A1409618372145',
#    'restricted': 0,
#    'updated_time': '2011-09-20T18:10:04Z',
#    'primary_genres': {'music_genre_list': []}}},
#  {'track': {'track_id': 1255863,
#    'track_name': 'The Bull / Delt',
#    'track_name_translation_list': [],
#    'track_rating': 1,
#    'commontrack_id': 1602627,
#    'instrumental': 0,
#    'explicit': 1,
#    'has_lyrics': 1,
#    'has_subtitles': 0,
#    'has_richsync': 0,
#    'num_favourite': 0,
#    'album_id': 10322989,
#    'album_name': 'H.N.I.C.',
#    'artist_id': 13816,
#    'artist_name': 'Prodigy',
#    'track_share_url': 'https://www.musixmatch.com/lyrics/Prodigy/The-Bull-Delt?utm_source=application&utm_campaign=api&utm_medium=University+of+Oxford%3A1409618372145',
#    'track_edit_url': 'https://www.musixmatch.com/lyrics/Prodigy/The-Bull-Delt/edit?utm_source=application&utm_campaign=api&utm_medium=University+of+Oxford%3A1409618372145',
#    'restricted': 0,
#    'updated_time': '2011-12-16T12:44:01Z',
#    'primary_genres': {'music_genre_list': []}}},
#  {'track': {'track_id': 123003785,
#    'track_name': 'Award Show Life',
#    'track_name_translation_list': [],
#    'track_rating': 11,
#    'commontrack_id': 11035984,
#    'instrumental': 0,
#    'explicit': 1,
#    'has_lyrics': 1,
#    'has_subtitles': 0,
#    'has_richsync': 0,
#    'num_favourite': 1,
#    'album_id': 25156079,
#    'album_name': 'H.N.I.C 3',
#    'artist_id': 13816,
#    'artist_name': 'Prodigy',
#    'track_share_url': 'https://www.musixmatch.com/lyrics/Prodigy/Award-Show-Life?utm_source=application&utm_campaign=api&utm_medium=University+of+Oxford%3A1409618372145',
#    'track_edit_url': 'https://www.musixmatch.com/lyrics/Prodigy/Award-Show-Life/edit?utm_source=application&utm_campaign=api&utm_medium=University+of+Oxford%3A1409618372145',
#    'restricted': 0,
#    'updated_time': '2012-07-03T11:10:04Z',
#    'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 1073,
#        'music_genre_parent_id': 18,
#        'music_genre_name': 'Hip-Hop',
#        'music_genre_name_extended': 'Hip Hop/Rap / Hip-Hop',
#        'music_genre_vanity': 'Hip-Hop-Rap-Hip-Hop'}},
#      {'music_genre': {'music_genre_id': 18,
#        'music_genre_parent_id': 34,
#        'music_genre_name': 'Hip Hop/Rap',
#        'music_genre_name_extended': 'Hip Hop/Rap',
#        'music_genre_vanity': 'Hip-Hop-Rap'}}]}}},
#  {'track': {'track_id': 55041094,
#    'track_name': 'Not a Stan',
#    'track_name_translation_list': [],
#    'track_rating': 32,
#    'commontrack_id': 26641001,
#    'instrumental': 0,
#    'explicit': 1,
#    'has_lyrics': 1,
#    'has_subtitles': 0,
#    'has_richsync': 0,
#    'num_favourite': 1,
#    'album_id': 17253806,
#    'album_name': 'The Most Infamous',
#    'artist_id': 13816,
#    'artist_name': 'Prodigy',
#    'track_share_url': 'https://www.musixmatch.com/lyrics/Prodigy/Not-a-Stan?utm_source=application&utm_campaign=api&utm_medium=University+of+Oxford%3A1409618372145',
#    'track_edit_url': 'https://www.musixmatch.com/lyrics/Prodigy/Not-a-Stan/edit?utm_source=application&utm_campaign=api&utm_medium=University+of+Oxford%3A1409618372145',
#    'restricted': 0,
#    'updated_time': '2014-04-12T00:44:05Z',
#    'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 1071,
#        'music_genre_parent_id': 18,
#        'music_genre_name': 'Gangsta Rap',
#        'music_genre_name_extended': 'Hip Hop/Rap / Gangsta Rap',
#        'music_genre_vanity': 'Hip-Hop-Rap-Gangsta-Rap'}},
#      {'music_genre': {'music_genre_id': 1073,
#        'music_genre_parent_id': 18,
#        'music_genre_name': 'Hip-Hop',
#        'music_genre_name_extended': 'Hip Hop/Rap / Hip-Hop',
#        'music_genre_vanity': 'Hip-Hop-Rap-Hip-Hop'}}]}}},
#  {'track': {'track_id': 122445864,
#    'track_name': 'Drive Thru Skit',
#    'track_name_translation_list': [],
#    'track_rating': 33,
#    'commontrack_id': 13734196,
#    'instrumental': 0,
#    'explicit': 1,
#    'has_lyrics': 1,
#    'has_subtitles': 0,
#    'has_richsync': 0,
#    'num_favourite': 0,
#    'album_id': 25096625,
#    'album_name': 'H.N.I.C',
#    'artist_id': 13816,
#    'artist_name': 'Prodigy',
#    'track_share_url': 'https://www.musixmatch.com/lyrics/Prodigy/Drive-Thru-Skit?utm_source=application&utm_campaign=api&utm_medium=University+of+Oxford%3A1409618372145',
#    'track_edit_url': 'https://www.musixmatch.com/lyrics/Prodigy/Drive-Thru-Skit/edit?utm_source=application&utm_campaign=api&utm_medium=University+of+Oxford%3A1409618372145',
#    'restricted': 0,
#    'updated_time': '2014-11-22T09:38:10Z',
#    'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 18,
#        'music_genre_parent_id': 34,
#        'music_genre_name': 'Hip Hop/Rap',
#        'music_genre_name_extended': 'Hip Hop/Rap',
#        'music_genre_vanity': 'Hip-Hop-Rap'}}]}}},
#  {'track': {'track_id': 58223035,
#    'track_name': 'Change',
#    'track_name_translation_list': [],
#    'track_rating': 35,
#    'commontrack_id': 26640996,
#    'instrumental': 0,
#    'explicit': 1,
#    'has_lyrics': 1,
#    'has_subtitles': 1,
#    'has_richsync': 0,
#    'num_favourite': 1,
#    'album_id': 17610576,
#    'album_name': 'The Bumpy Johnson Album',
#    'artist_id': 13816,
#    'artist_name': 'Prodigy',
#    'track_share_url': 'https://www.musixmatch.com/lyrics/Prodigy/Change?utm_source=application&utm_campaign=api&utm_medium=University+of+Oxford%3A1409618372145',
#    'track_edit_url': 'https://www.musixmatch.com/lyrics/Prodigy/Change/edit?utm_source=application&utm_campaign=api&utm_medium=University+of+Oxford%3A1409618372145',
#    'restricted': 0,
#    'updated_time': '2014-07-08T06:38:36Z',
#    'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 1071,
#        'music_genre_parent_id': 18,
#        'music_genre_name': 'Gangsta Rap',
#        'music_genre_name_extended': 'Hip Hop/Rap / Gangsta Rap',
#        'music_genre_vanity': 'Hip-Hop-Rap-Gangsta-Rap'}},
#      {'music_genre': {'music_genre_id': 1073,
#        'music_genre_parent_id': 18,
#        'music_genre_name': 'Hip-Hop',
#        'music_genre_name_extended': 'Hip Hop/Rap / Hip-Hop',
#        'music_genre_vanity': 'Hip-Hop-Rap-Hip-Hop'}}]}}}]

# %%
artists = [ 'slipknot','prodigy','system of a down','marina','selena gomez','modern talking','imagine dragons','metallica','britney spears','kiss','bhad barbie','my chemical romance','rammstein','pink floyd','joy division','bones','our last night','twenty one pilots','conan gray','drake','geazy','joji','billie eilish','david bowie','ariana grande','travis scott','jack stauber','sting','paramore','red hot chilli peppers','the weeknd','lil peep','avicii','xxxtentacion','adele','niall horan','loic nottet','disturbed','bring me the horizon','queen','ghostemane','chase atlantic','onerepublic','die antwood','depeche mode','hollywood undead','frank ocean','asap rocky','blackbear','logic','oasis','liam gallagher',' halsey','aurora','tom odell','arctic monkeys','the neighbourhood','daft punk','mac demarco','tame impala','radiohead','lana del rey','yungblud','troye sivan','alice in chains','pristin','kreayshawn','u2','banks','eminem','beyonce','blackpink','schafter']
def artist_list_to_track_ids(alist):
    track_ids = []
    for a in alist:
        tracks = requests.get(url+'track.search', {'apikey':apikey, 'q_artist':a.encode('utf-8')}).json()['message']['body']['track_list'][:20]
        for track in tracks:
            if track['track']['has_lyrics']==1:
                track_ids += [track['track']['track_id']]
            else:
                continue
    return(track_ids)

# %%
print(len(artists))
trids=[]
trids = arist_list_to_track_ids(artists) #trids reset to [] to make sure I won't waste any calls now
#np.save('trids', trids)
# Out:
# 73

# %%
allyrics=[]
for trid in trids:
    lyrics = requests.get(url+'track.lyrics.get', {'apikey':apikey, 'track_id':trid})
    allyrics+=[(lyrics.json()['message']['body']['lyrics']['lyrics_body'], trid)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-5824ca8b11fa> in <module>
#       3     lyrics = requests.get(url+'track.lyrics.get', {'apikey':apikey, 'track_id':trid})
#       4     allyrics+=[(lyrics.json()['message']['body']['lyrics']['lyrics_body'], trid)]
# ----> 5 np.save('allyrics', np.array(alllyrics))
#
# NameError: name 'alllyrics' is not defined

# %%
#np.save('allyrics', np.array(allyrics)) #commented out not to download lyrics again

# %%
alllyrics = np.load('allyrics.npy')

# %%
alllyrics[:3,0]
# Out:
# array(["Yes, welcome back, to Infamous radio, 3-57 FM\nI'd like to thank all the callers that called in earlier\nThe love is much appreciated\nLadies call up, the request lines are still open\nWe Playin'whatever you wanna hear\nRight now, we got a special request\nGonna play this young man record right here\nIt's kind of fresh\n\nOver here we tie your ass up to a chair\nAnd throw bricks at you top speed for ya head\nSlow pain, torture style\nBetter hope one of these shits knock you out\nI enjoy watching you suffer, scream, shout\nAnd all that badman shit out the window\nAnd while he gone, Im having his bimbo\nLive is ill, and it make sharp turns bro\nNiggas is foul, they run up on you quick loc\nNiggas is foul, they run up on you quick loc, and\nLight you up, stop your green\nFrom going any further, now you don't think\nSo tough, you think you so tough?\nYou need to be cool and just get your bucks\nShould've been cool and just got the ones\n...\n\n******* This Lyrics is NOT for Commercial use *******\n(1409618372145)",
#        "There are two kinds of people in this world\nThose who make things happen and those who just watch and coppin over us\nI get my rush makin brush styles\nThey simulate me but imitation is the highest form of flattery\nSo gas me kid wit yo blandishment\nIt only makes me realize how much you really on my dick\nSuckin all the flavor off of my love like you's a bitch\nSave something for my chick but go ahead get yo lick\nI've been doing this since Machiavelli made hits\nBiggie Smalls said and Mobb Deep started done lenglish\n40 years changed and Hennessey\nShootin videos in them projects in Queens\n\nNothing stays the same, hip-hop goes through eras my man\nThe only thing constant is change\nNow ask yourself, are you a follower or a leader?\nLeaders create and followers just follow the leaders\n...\n\n******* This Lyrics is NOT for Commercial use *******\n(1409618372145)",
#        "Yeah, that's right, of course\nUh, uh\nYeah, aiyyo, uh-huh\n\nField Marshal P\nSoldier you step inside my room solute\n(Solute)\nAt attention, pay attention\nWhen P say something it's the truth\n\nThe universe is my witness\n(Uh-huh)\nIt's all what these demon cops tried to do\nIt's all our leaders that got hit\nIt's all the shooting that hit our leaders too\n\nNigga I'ma vet, on the streets I'ma King\nPush it to the maximum when I do my thang\nMy words will shock you, my songs will scare you\nYou fit to die real soon, let me prepare you\n\nFor that rectangle box, you deserve to die, you dirty lil fuck\nYou ungrateful, un-loyal, I'll have my nigga Un take care of you\nOr my nigga Fox, you just light work, real simple\nI'll pick up the pistol and hit up your temple\n\nDemolish your rental, you cheap fuck, bury 'em in his cheap suit\nAshes to dust, you're not a revolutionary, you're a punk\nYou're not a rebel soldier; just leave it up to us\nI'ma insurgent, I put work in, check my card, listen to my verses\n\nField Marshal P\nSoldier you step inside my room solute\n(Solute)\nAt attention, pay attention\nWhen P say something it's the truth\n...\n\n******* This Lyrics is NOT for Commercial use *******\n(1409618372145)"],
#       dtype='<U1194')
